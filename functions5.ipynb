# %%
#AMB2296

# %%
a=10
b=20

def sum_fn(m,n):
    add = m+n
    print(add)

sum_fn(a,b)
# Out:
# 30

# %%
def sum_fn(m,n):
  add = m + n
  return add

print(sum_fn(a,b))
# Out:
# 30

# %%
def sumfn ():
  add=a+b
  print(add)
sumfn()
# Out:
# 30

# %%
def sumfn():
  add=a+b
  return add
print(sumfn())
# Out:
# 30

# %%
def max (num1,num2):
  if num1>num2:
    result=num1
  else:
    result=num2
  return result
  z=max(10,20)
  print(z)
print(max(10,20))
# Out:
# 20

# %%
n=int(input("enter a number"))
sum=0
for i in range(1,n+1):
  sum=sum+i
print(sum)
# Out:
# enter a number5
# 1
# 3
# 6
# 10
# 15

# %%
n=int(input("enter a number"))
factorial=1
for i in range(1,n+1):
  factorial=factorial*i
print(factorial)
# Out:
# enter a number4
# 24

# %%
def fact (m):
    fact=1
    if(m>0):
        for i in range(1,m+1):
            fact=fact*i
        print("factorial of",m,"ïs",fact)
    else:
        print("enter a valid number")
n=int(input("enter the number"))
fact(n)
# Out:
# enter the number6
# factorial of 6 ïs 720

# %%
def fact (m):
    fact=1
    if(m>0):
        for i in range(1,m+1):
            fact=fact*i
        return fact
    else:
        print("enter a valid number")
n=int(input("enter the number"))
z=fact(n)
print(z)
# Out:
# enter the number6
# 720

# %%
def fact (m):
    m=int(input("enter the number"))
    fact=1
    if(m>0):
        for i in range(1,m+1):
            fact=fact*i
        print("factorial of",m,"ïs",fact)
    else:
        print("enter a valid number")

fact(n)
# Out:
# enter the number7
# factorial of 7 ïs 5040

# %%
def fact (m):
    fact=1
    if(m>0):
        for i in range(1,m+1):
            fact=fact*i
        return fact
    else:
        print("enter a valid number")
n=int(input("enter the number"))
z=fact(n)
print(z)
#
# Out:
# enter the number7
# 5040

# %%
def fun(x):
  print("local x is :",x)
  x=2
  print("local x is :",x)
x=20
fun(x)
print(" x is still :",x)
# Out:
# local x is : 20
# local x is : 2
#  x is still : 20

# %%
def fun(x):
  y=2
  print("change y to:",y)
y=50
fun(x)
print("value of y is :",y)
# Out:
# change y to: 2
# value of y is : 50

# %%
def fun(x):
  global y
  print("y is:",y)
  y=2
  print("changed y to:",y)
y=50
fun(x)
print("y is still:",y)
# Out:
# y is: 50
# changed y to: 2
# y is still: 2

# %%
total=0
def sum(arg1,arg2):
  total=arg1+arg2
  print("inside the function local total:",total)
  return total
sum(10,20)
print("outside the function global total:",total)
# Out:
# inside the function local total: 30
# outside the function global total: 0

# %%
def printme(str):
   print(str)
   return
printme("hello")
printme(1234)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /tmp/ipython-input-1915398876.py in <cell line: 0>()
#       2    print(str)
#       3    return
# ----> 4 printme("hello")
#       5 printme(1234)
#
# /tmp/ipython-input-1915398876.py in printme(str)
#       1 def printme(str):
# ----> 2    print(str)
#       3    return
#       4 printme("hello")
#       5 printme(1234)
#
# /tmp/ipython-input-3769711630.py in print(str)
#       1 def print(str):
# ----> 2    print(str)
#       3    return
#       4 printme("hello")
#       5 printme("1234")
#
# ... last 1 frames repeated, from the frame below ...
#
# /tmp/ipython-input-3769711630.py in print(str)
#       1 def print(str):
# ----> 2    print(str)
#       3    return
#       4 printme("hello")
#       5 printme("1234")
#
# RecursionError: maximum recursion depth exceeded

# %%
def printme(str):
   print(str)
   return
printme("hello")
printme(str="my string")
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /tmp/ipython-input-1378677163.py in <cell line: 0>()
#       2    print(str)
#       3    return
# ----> 4 printme("hello")
#       5 printme(str="my string")
#
# /tmp/ipython-input-1378677163.py in printme(str)
#       1 def printme(str):
# ----> 2    print(str)
#       3    return
#       4 printme("hello")
#       5 printme(str="my string")
#
# /tmp/ipython-input-3769711630.py in print(str)
#       1 def print(str):
# ----> 2    print(str)
#       3    return
#       4 printme("hello")
#       5 printme("1234")
#
# ... last 1 frames repeated, from the frame below ...
#
# /tmp/ipython-input-3769711630.py in print(str)
#       1 def print(str):
# ----> 2    print(str)
#       3    return
#       4 printme("hello")
#       5 printme("1234")
#
# RecursionError: maximum recursion depth exceeded

# %%
import builtins

def fun(a,b=5,c=10):
    builtins.print("a is:",a,"and b is:",b,"and c is:",c)
fun(3,7)
fun(25,c=24)
fun(c=50,a=100)
# Out:
# a is: 3 and b is: 7 and c is: 10
# a is: 25 and b is: 5 and c is: 24
# a is: 100 and b is: 5 and c is: 50

# %%
def check(name,*marks):
  print(name)
  print(marks)
check("XYZ",10,20,30)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /tmp/ipython-input-533424889.py in <cell line: 0>()
#       2   print(name)
#       3   print(marks)
# ----> 4 check("XYZ",10,20,30)
#
# /tmp/ipython-input-533424889.py in check(name, *marks)
#       1 def check(name,*marks):
# ----> 2   print(name)
#       3   print(marks)
#       4 check("XYZ",10,20,30)
#
# /tmp/ipython-input-3769711630.py in print(str)
#       1 def print(str):
# ----> 2    print(str)
#       3    return
#       4 printme("hello")
#       5 printme("1234")
#
# ... last 1 frames repeated, from the frame below ...
#
# /tmp/ipython-input-3769711630.py in print(str)
#       1 def print(str):
# ----> 2    print(str)
#       3    return
#       4 printme("hello")
#       5 printme("1234")
#
# RecursionError: maximum recursion depth exceeded
