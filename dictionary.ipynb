# %%
# SOWNDARYA.M-AMB2260

# %%
# A farmer maintains a dictionary containing the names of crops and their respective yields (in quintals per acre).

crop_yield = {
    "Rice": 120,
    "Wheat": 85,
    "Maize": 60
}

# %%
#find the number of crops cultivated by the farmer

num_crops = len(crop_yield)
print("Number of Crops Cultivated:", num_crops)
# Out:
# Number of Crops Cultivated: 3

# %%
#display the yield of wheat

print("Wheat Yield:", crop_yield["Wheat"])
# Out:
# Wheat Yield: 85

# %%
# add a crop pulses with yield 45

crop_yield["Pulses"] = 45
print(crop_yield)
# Out:
# {'Rice': 120, 'Wheat': 85, 'Maize': 60, 'Pulses': 45}

# %%
#update the yield of rice to 130

crop_yield["Rice"] = 130
print(crop_yield)
# Out:
# {'Rice': 130, 'Wheat': 85, 'Maize': 60, 'Pulses': 45}

# %%
#display all crop names cultivated by farmer

crop_yields = crop_yield.keys()
print("Crops Cultivated:", list(crop_yields))
# Out:
# Crops Cultivated: ['Rice', 'Wheat', 'Maize', 'Pulses']

# %%
#display all crop yields
#
yields = crop_yield.values()
print("Crop Yields:", list(yields))
# Out:
# Crop Yields: [130, 85, 60, 45]

# %%
#check whether 'Sugarcane' is cultivated by the farmer

print("Sugarcane" in crop_yield)
# Out:
# False

# %%
# How do you get the yield of maize from the dictionary?

print("Maize Yield:", crop_yield["Maize"])

print("Maize Yield:", crop_yield.get("Maize"))
# Out:
# Maize Yield: 60
# Maize Yield: 60

# %%
#How do you get the yield of jowar from the dictionary

print("Maize Yield:", crop_yield["Jowar"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 4
#       1 #How do you get the yield of jowar from the dictionary
# ----> 4 print("Maize Yield:", crop_yield["Jowar"])
#
# KeyError: 'Jowar'

# %%
print("Jowar Yield:", crop_yield["Jowar"]) if "Jowar" in crop_yield else print("Jowar not found")
# Out:
# Jowar not found

# %%
#How do you get the yield of jowar from the dictionary

print("Jowar Yield:", crop_yield.get("Jowar"))
# Out:
# Jowar Yield: None

# %%
#How do you get the yield of jowar from the dictionary with proper caption

print("Jowar Yield:", crop_yield.get("Jowar", "Not Cultivated"))
# Out:
# Jowar Yield: Not Cultivated

# %%
#increase the yield of wheat by 10

crop_yield["Wheat"] += 10
print(crop_yield)
# Out:
# {'Rice': 130, 'Wheat': 95, 'Maize': 60, 'Pulses': 45}

# %%
#remove 'Maize' from the dictionary

#crop_yield.pop("Maize")
# or
del crop_yield["Maize"]   # if not present error
print(crop_yield)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 4
#       1 #remove 'Maize' from the dictionary
#       2 #crop_yield.pop("Maize")
#       3 #or
# ----> 4 del crop_yield["Maize"]
#       5 print(crop_yield)
#
# KeyError: 'Maize'

# %%
#calculate total yield of all crops

total_yield = sum(crop_yield.values())
print("Total Yield of all Crops:", total_yield)
# Out:
# Total Yield of all Crops: 260

# %%
#display each crop and its yield using loop

for crop, yield_value in crop_yield.items():
    print(crop, ":", yield_value)
# Out:
# Rice : 130
# Wheat : 85
# Pulses : 45

# %%
# copy of a dictionary

crop_yield2 = crop_yield.copy()
print("Copy of crop_yield:", crop_yield2)
# Out:
# Copy of crop_yield: {'Rice': 130, 'Wheat': 95, 'Maize': 60, 'Pulses': 45}

# %%
#clear all entries from new dictionary and display

crop_yield2.clear()
print("After clearing, crop_yield2:", crop_yield2)
# Out:
# After clearing, crop_yield2: {}

# %%
del crop_yield2
print(crop_yield2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 2
#       1 del crop_yield2
# ----> 2 print(crop_yield2)
#
# NameError: name 'crop_yield2' is not defined

# %%
# Creating a dictionary using dict()
crops = dict({
    "Rice": {"Season": "Kharif", "Yield": "4 tons/ha", "Price": 40},
    "Wheat": {"Season": "Rabi", "Yield": "3 tons/ha", "Price": 35},
    "Maize": {"Season": "Kharif", "Yield": "5 tons/ha", "Price": 30}
})

# keys()
print("Crop Names:", crops.keys())
print(list(crops.keys()))

# values()
print("\n Crop Details:", crops.values())
print(list(crops.values()))

# items()
print("\nAll Crop Items:", crops.items())
print(list(crops.items()))

# get()
print("Rice Details:", crops.get("Rice"))

# setdefault()
crops.setdefault("Barley", {"Season": "Rabi", "Yield": "2 tons/ha", "Price": 28})
print("After setdefault:", crops)

# update()
crops.update({"Sugarcane": {"Season": "Annual", "Yield": "70 tons/ha", "Price": 5}})
print("After update:", crops)

# pop()
removed_crop = crops.pop("Maize")
print("Removed Crop:", removed_crop)

# popitem()
last_item = crops.popitem()
print("Last Removed Item:", last_item)

# copy()
crops_copy = crops.copy()
print("Copied Dictionary:", crops_copy)

# clear()
crops.clear()
print("After clear:", crops)
# Out:
# Crop Names: dict_keys(['Rice', 'Wheat', 'Maize'])
# ['Rice', 'Wheat', 'Maize']
#
#  Crop Details: dict_values([{'Season': 'Kharif', 'Yield': '4 tons/ha', 'Price': 40}, {'Season': 'Rabi', 'Yield': '3 tons/ha', 'Price': 35}, {'Season': 'Kharif', 'Yield': '5 tons/ha', 'Price': 30}])
# [{'Season': 'Kharif', 'Yield': '4 tons/ha', 'Price': 40}, {'Season': 'Rabi', 'Yield': '3 tons/ha', 'Price': 35}, {'Season': 'Kharif', 'Yield': '5 tons/ha', 'Price': 30}]
#
# All Crop Items: dict_items([('Rice', {'Season': 'Kharif', 'Yield': '4 tons/ha', 'Price': 40}), ('Wheat', {'Season': 'Rabi', 'Yield': '3 tons/ha', 'Price': 35}), ('Maize', {'Season': 'Kharif', 'Yield': '5 tons/ha', 'Price': 30})])
# [('Rice', {'Season': 'Kharif', 'Yield': '4 tons/ha', 'Price': 40}), ('Wheat', {'Season': 'Rabi', 'Yield': '3 tons/ha', 'Price': 35}), ('Maize', {'Season': 'Kharif', 'Yield': '5 tons/ha', 'Price': 30})]
# Rice Details: {'Season': 'Kharif', 'Yield': '4 tons/ha', 'Price': 40}
# ...
